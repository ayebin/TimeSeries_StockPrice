# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib as mpl
import seaborn as sns

# %%
def feature_dist(date, feature, x_size, y_size, title, x_label, y_label, grid_flag):
  fig, ax = plt.subplots(figsize = (x_size, y_size))
  ax.plot(date, feature)
  ax.xaxis.set_major_locator(mdates.YearLocator())
  ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

  plt.title(title)
  plt.xlabel(x_label)
  plt.ylabel(y_label)
  plt.xticks(rotation=45)
  plt.grid(grid_flag)
  plt.show()

# %% [markdown]
# ## 기준금리

# %%
us_base_rate = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/미국 기준금리.xlsx')

# %%
kor_base_rate = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/한국 기준금리.xlsx')

# %%
us_date = pd.to_datetime(us_base_rate['Date'])
us_base = us_base_rate['기준금리']

# %%
kor_date = pd.to_datetime(kor_base_rate['Date'])
kor_base = kor_base_rate['한국기준금리']

# %%
plt.figure(figsize = (12,6))

plt.plot(us_date, us_base, color = 'r', marker = 'o', label = 'US Base Rate')
plt.plot(kor_date, kor_base, color = 'b', marker = 'o', label = 'KOR Base Rate')

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

plt.title('Base Rate')
plt.xlabel('Date')
plt.ylabel('Base Rate')
plt.legend()
plt.xticks(rotation = 45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10년 금리

# %%
us_10_treasury_bond = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/미국10년금리.xlsx')

# %%
kor_10_treasury_bond = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/한국 10년금리.xlsx')

# %%
us_date = pd.to_datetime(us_10_treasury_bond['Date'])
us_treasury_bond = us_10_treasury_bond['미국 10년 금리']

# %%
kor_10_treasury_bond.drop(columns = ['Unnamed: 2', 'Unnamed: 3',
       'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
       'Unnamed: 9'], inplace = True)
kor_10_treasury_bond.head(10)
# Out:
#            기간  2000-12-18 ~ 2024-11-15
# 0  2000-01-03                      NaN
# 1  2000-01-04                      NaN
# 2  2000-01-05                      NaN
# 3  2000-01-06                      NaN
# 4  2000-01-07                      NaN
# 5  2000-01-10                      NaN
# 6  2000-01-11                      NaN
# 7  2000-01-12                      NaN
# 8  2000-01-13                      NaN
# 9  2000-01-14                      NaN

# %%
kor_10_treasury_bond = kor_10_treasury_bond.rename(columns = {'기간':'Date', '2000-12-18 ~ 2024-11-15':'한국 10년 금리'})
kor_10_treasury_bond.head(10)
# Out:
#          Date  한국 10년 금리
# 0  2000-01-03        NaN
# 1  2000-01-04        NaN
# 2  2000-01-05        NaN
# 3  2000-01-06        NaN
# 4  2000-01-07        NaN
# 5  2000-01-10        NaN
# 6  2000-01-11        NaN
# 7  2000-01-12        NaN
# 8  2000-01-13        NaN
# 9  2000-01-14        NaN

# %%
kor_date = pd.to_datetime(kor_10_treasury_bond['Date'])
kor_treasury_bond = kor_10_treasury_bond['한국 10년 금리']

# %%
plt.figure(figsize = (12,6))

plt.plot(us_date, us_treasury_bond, color = 'r', label = '10Y US Treasury Bond Rate')
plt.plot(kor_date, kor_treasury_bond, color = 'b', label = '10Y KOR Treasury Bond Rate')

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

plt.title('10 Year Treasury Bond Rate')
plt.xlabel('Date')
plt.ylabel('Treasury Bond Rate')
plt.legend()
plt.xticks(rotation = 45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 국제 유가

# %%
fuel = pd.read_csv(('/content/drive/MyDrive/Time Series Project/Stock Price/data/final_fuel_price.csv'))

# %%
fuel.head()
# Out:
#          Date    WTI
# 0  2001-01-02  27.21
# 1  2001-01-03  28.00
# 2  2001-01-04  28.14
# 3  2001-01-05  27.95
# 4  2001-01-08  27.32

# %%
fuel_date = pd.to_datetime(fuel['Date'])
fuel_price = fuel['WTI']

# %%
plt.figure(figsize = (12,6))

plt.plot(fuel_date, fuel_price)

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

plt.title('Fuel Price(WTI)')
plt.xlabel('Date')
plt.ylabel('WTI')
plt.xticks(rotation = 45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 환율

# %%
exchange_rate = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/환율.xlsx')

# %%
exchange_rate = exchange_rate.iloc[6:]
exchange_rate = exchange_rate.drop(columns = ['Unnamed: 2', 'Unnamed: 3'])
exchange_rate = exchange_rate.rename(columns = {'주요국 통화의 대원화 환율': 'Date', 'Unnamed: 1':'환율'})
exchange_rate['Date'] = pd.to_datetime(exchange_rate['Date'])
exchange_rate.head(10)
# Out:
#          Date     환율
# 6  1990-03-02    693
# 7  1990-03-05  695.1
# 8  1990-03-06  696.4
# 9  1990-03-07  697.6
# 10 1990-03-08  698.1
# 11 1990-03-09  698.6
# 12 1990-03-12  698.8
# 13 1990-03-13  698.6
# 14 1990-03-14  697.9
# 15 1990-03-15  696.5

# %%
exchange_date = exchange_rate['Date']
exchange = exchange_rate['환율']

# %%
plt.figure(figsize = (12,6))

plt.plot(exchange_date, exchange)

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

plt.title('Exchange Rate (Won - Dollar)')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.xticks(rotation = 45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 대통령 정당

# %%
president = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/President.xlsx')

# %%
president.head()
# Out:
#         Date US_President KOR_President
# 0 2001-01-01          민주당       새정치국민회의
# 1 2001-01-02          민주당       새정치국민회의
# 2 2001-01-03          민주당       새정치국민회의
# 3 2001-01-04          민주당       새정치국민회의
# 4 2001-01-05          민주당       새정치국민회의

# %%
president['Date'] = pd.to_datetime(president['Date'])
date = pd.to_datetime(president['Date'])

# %%
list1 = ['민주당']
list2 = ['공화당']
president['re_us'] = president['US_President'].apply(lambda x: 'Democratic' if x in list1 else 'Republican')

# %%
list1 = ['새정치국민회의', '새천년민주당', '더불어민주당']
list2 = ['한나라당', '새누리당', '국민의힘']
list3 = ['무소속']
president['re_kor'] = president['KOR_President'].apply(lambda x: 'Progressive' if x in list1 else ('Conservative' if x in list2 else 'Neutral'))

# %%
us_ori = president['US_President']
us_re = president['re_us']
kor_ori = president['KOR_President']
kor_re = president['re_kor']

# %%
sns.catplot(data = president,
            x = 'Date', y = 're_us',
            kind = 'strip', height = 6, aspect = 4)

plt.title('US President Party', fontsize = 20)
plt.xlabel('Date', fontsize = 15)
plt.ylabel('Party Type', fontsize = 15)
plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
plt.show()

# %%
sns.catplot(data = president,
            x = 'Date', y = 're_kor',
            kind = 'strip', height = 6, aspect = 4)

plt.title('KOR President Party', fontsize = 20)
plt.xlabel('Date', fontsize = 15)
plt.ylabel('Party Type', fontsize = 15)
plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 폰 점유율

# %%
phone_market_share = pd.read_excel('/content/drive/MyDrive/Time Series Project/Stock Price/data/폰 점유율 1.xlsx')

# %%
phone_market_share.head()
# Out:
#         Date  Samsung
# 0 2001-01-01      7.1
# 1 2002-01-01      9.7
# 2 2003-01-01     10.5
# 3 2004-01-01     12.6
# 4 2005-01-01     12.7

# %%
phone_market_share['Date'] = pd.to_datetime(phone_market_share['Date'])
phone_date = phone_market_share['Date']

# %%
# 주기 열 추가
phone_market_share['frequency'] = ['Yearly' if d.year <= 2015 else 'Quarterly' for d in phone_market_share['Date']]

# 시각화
plt.figure(figsize=(10, 6))
sns.lineplot(data=phone_market_share, x='Date', y='Samsung', hue='frequency', style='frequency', markers=True, dashes=False)

# 제목 및 레이블
plt.title("Samsung Phone Market Share", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Market Share Rate", fontsize=14)
plt.xticks(rotation=45)
plt.legend(title="Frequency")
plt.show()

# %% [markdown]
# ## 코로나

# %%
covid = pd.read_csv('/content/drive/MyDrive/Time Series Project/Stock Price/data/merged_data_yb.csv')
covid.head()
# Out:
#    Unnamed: 0  us_base  us_10  kor_base  kor_10    WTI  exchange  \
# 0  2001-01-01      6.5   5.12      5.25    7.21    NaN    1264.5
# 1  2001-01-02      6.5   4.92      5.25    7.18  27.21    1276.4
# 2  2001-01-03      6.0   5.14      5.25    7.15  28.00    1270.1
# 3  2001-01-04      6.0   5.03      5.25    6.85  28.14    1255.0
# 4  2001-01-05      6.0   4.93      5.25    6.68  27.95    1263.5
#
#    US_president  KOR_president  Samsung  Samsung_spline  Covid-19
# 0             1              1      7.1        7.100000     False
# 1             1              1      7.1        7.114173     False
# 2             1              1      7.1        7.128294     False
# 3             1              1      7.1        7.142364     False
# 4             1              1      7.1        7.156383     False

# %%
covid['Unnamed: 0'] = pd.to_datetime(covid['Unnamed: 0'])

# %%
covid = covid[['Unnamed: 0', 'Covid-19']]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6196 entries, 0 to 6195
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6196 non-null   datetime64[ns]
#  1   Covid-19    6196 non-null   bool
# dtypes: bool(1), datetime64[ns](1)
# memory usage: 54.6 KB

# %%
sns.catplot(data = covid,
            x = 'Unnamed: 0', y = 'Covid-19',
            kind = 'strip', height = 6, aspect = 4)

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
plt.title('Covid-19', fontsize = 20)
plt.xlabel('Date', fontsize = 15)
plt.ylabel('Covid T/F', fontsize = 15)
plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 삼성

# %% [markdown]
# 삼성전자(영업이익,당기순이익,자본총계,부채총계,매출액)

# %%
samsung_data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/삼전.xlsx')
samsung_data.head()
# Out:
#             Date  Operating_Profit  Net_Profit  Total_Equity  \
# 0  2024-3quarter           9183371    10100904     386281363
# 1  2024-2quarter          10443878     9841345     383526671
# 2  2024-1quarter           6606009     6754708     371916124
# 3  2023-4quarter           2824717    15487100     363677865
# 4  2023-3quarter           2433534     5844171     363892643
#
#   Total_Liabilities   Revenue
# 0         105025954  79098731
# 1         102231027  74068302
# 2          98983688  71915601
# 3          92228115  67779938
# 4          90573804  67404652

# %%
samsung_data['Date'] = pd.to_datetime(samsung_data['Date'], format='%Y-%mquarter')
samsung_data['Operating_Profit'] = pd.to_numeric(samsung_data['Operating_Profit'], errors='coerce')

plt.figure(figsize=(10, 6))
plt.plot(samsung_data['Date'], samsung_data['Operating_Profit'], marker='o', color='blue')
plt.title('Operating Profit')
plt.xlabel('Date')
plt.ylabel('Operating Profit')
plt.grid(True)
plt.show()

# %%
samsung_data['Net_Profit'] = pd.to_numeric(samsung_data['Net_Profit'], errors='coerce')

plt.figure(figsize=(10, 6))
plt.plot(samsung_data['Date'], samsung_data['Net_Profit'], marker='o', color='green')
plt.title('Net Profit')
plt.xlabel('Date')
plt.ylabel('Net Profit')
plt.grid(True)
plt.show()

# %%
samsung_data['Total_Equity'] = pd.to_numeric(samsung_data['Total_Equity'], errors='coerce')

plt.figure(figsize=(10, 6))
plt.plot(samsung_data['Date'], samsung_data['Total_Equity'], marker='o', color='orange')
plt.title('Total Equity')
plt.xlabel('Date')
plt.ylabel('Total Equity')
plt.grid(True)
plt.show()

# %%
samsung_data['Total_Liabilities'] = pd.to_numeric(samsung_data['Total_Liabilities'], errors='coerce')

plt.figure(figsize=(10, 6))
plt.plot(samsung_data['Date'], samsung_data['Total_Liabilities'], marker='o', color='red')
plt.title('Total Liabilities')
plt.xlabel('Date')
plt.ylabel('Total Liabilities')
plt.grid(True)
plt.show()

# %%
samsung_data['Revenue'] = pd.to_numeric(samsung_data['Revenue'], errors='coerce')

plt.figure(figsize=(10, 6))
plt.plot(samsung_data['Date'], samsung_data['Revenue'], marker='o', color='purple')
plt.title('Revenue')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.grid(True)
plt.show()
